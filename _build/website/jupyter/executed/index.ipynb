# %% [markdown]
# # Text Analysis with Topic Models for the Humanities and Social Sciences
#
# *Text Analysis with Topic Models for the Humanities and Social Sciences* (TAToM)
# consists of a series of tutorials covering basic procedures in quantitative text
# analysis. The tutorials cover the preparation of a text corpus for analysis and
# the exploration of a collection of texts using topic models and machine
# learning.
#
# These tutorials cover basic as well as somewhat advanced procedures and make
# extensive use of the Python programming language to organize, analyze, and
# visualize data.
#
# These tutorials are written by [Allen Riddell](http://ariddell.org).  Comments
# are welcome, as are reports of bugs and typos. Please use the [project’s issue
# tracker](https://github.com/ariddell/tatom/issues).

# %% [markdown]
# ## Contents
#
# - [Preliminaries](preliminaries.html)
#   - [Required Python packages](preliminaries.html#required-python-packages)
#   - [Installing Python](preliminaries.html#installing-python)
#   - [Installing Python packages](preliminaries.html#installing-python-packages)
# - [Getting started](getting_started.html)
#   - [For those new to Python](getting_started.html#for-those-new-to-python)
#   - [For those new to NumPy](getting_started.html#for-those-new-to-numpy)
#   - [For those new to Matplotlib](getting_started.html#for-those-new-to-matplotlib)
# - [Working with text](working_with_text.html)
#   - [Creating a document-term matrix](working_with_text.html#creating-a-document-term-matrix)
#   - [Comparing texts](working_with_text.html#comparing-texts)
#   - [Visualizing distances](working_with_text.html#visualizing-distances)
#   - [Clustering texts based on distance](working_with_text.html#clustering-texts-based-on-distance)
#   - [Exercises](working_with_text.html#exercises)
# - [Preprocessing](preprocessing.html)
#   - [Tokenizing](preprocessing.html#tokenizing)
#   - [Chunking](preprocessing.html#chunking)
#   - [Grouping](preprocessing.html#grouping)
#   - [Exercises](preprocessing.html#exercises)
# - [Feature selection: finding distinctive words](feature_selection.html)
#   - [Measuring “distinctiveness”](feature_selection.html#measuring-distinctiveness)
#   - [Bayesian group comparison](feature_selection.html#bayesian-group-comparison)
#   - [Log likelihood ratio and $ \chi^2 $ feature selection](feature_selection.html#log-likelihood-ratio-and-chi-2-feature-selection)
#   - [Mutual information feature selection](feature_selection.html#mutual-information-feature-selection)
#   - [Feature selection as exploratory data analysis](feature_selection.html#feature-selection-as-exploratory-data-analysis)
#   - [Exercises](feature_selection.html#exercises)
# - [Topic modeling with MALLET](topic_model_mallet.html)
#   - [Running MALLET](topic_model_mallet.html#running-mallet)
#   - [Processing MALLET output](topic_model_mallet.html#processing-mallet-output)
#   - [Inspecting the topic model](topic_model_mallet.html#inspecting-the-topic-model)
# - [Topic modeling in Python](topic_model_python.html)
#   - [Using Non-negative matrix factorization](topic_model_python.html#using-non-negative-matrix-factorization)
#   - [Inspecting the NMF fit](topic_model_python.html#inspecting-the-nmf-fit)
# - [Visualizing topic models](topic_model_visualization.html)
#   - [Visualizing topic shares](topic_model_visualization.html#visualizing-topic-shares)
#   - [Visualizing topic-word associations](topic_model_visualization.html#visualizing-topic-word-associations)
# - [Visualizing trends](visualizing_trends.html)
#   - [Plotting trends](visualizing_trends.html#plotting-trends)
# - [Classification, Machine Learning, and Logistic Regression](classification_logistic_regression.html)
#   - [Predicting genre classifications](classification_logistic_regression.html#predicting-genre-classifications)
#   - [Logistic regression](classification_logistic_regression.html#logistic-regression)
# - [Case study: Racine’s early and late tragedies ](case_study_racine.html)
#   - [Corpus: sixty tragedies](case_study_racine.html#corpus-sixty-tragedies)
#   - [Racine’s atypical plays](case_study_racine.html#racine-s-atypical-plays)
# - [Datasets](datasets.html)
#   - [British novels](datasets.html#british-novels)
#   - [French plays](datasets.html#french-plays)
#   - [Les Misérables](datasets.html#les-miserables)
#   - [Stopword lists](datasets.html#stopword-lists)
# - [References](references.html)
#
#
# <img src="_static/plot_doctopic_heatmap.png" alt="Heatmap of topic shares in the ``austen-brontë`` corpus. See :ref:`topic_model_visualization`." style="width:60%;height:60%">
#
#
# <img src="_static/plot_word_topic.png" alt="Word associated with topics ``austen-brontë`` corpus. See :ref:`topic_model_visualization`." style="width:60%;height:60%">
